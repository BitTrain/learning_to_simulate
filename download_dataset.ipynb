# %% [markdown]
# # Download datasets
#
# ### [Sanchez-Gonzalez et al.](https://github.com/google-deepmind/deepmind-research/tree/master/learning_to_simulate) (2020)
#
# ### Datasets used for Learning to Simulate Complex Physics with Graph Neural Networks.

# %%
from google.colab import drive
drive.mount("/content/drive")

# Path to project, adjust as needed
# %cd /content/drive/My\ Drive/Colab\ Notebooks/1td808/learning_to_simulate/

# %%
SELECTED_DATASETS = [
    # "WaterDrop",
    # "Water",
    # "Sand",
    # "Goop",
    # "MultiMaterial",
    # "RandomFloor",
    # "WaterRamps",
    # "SandRamps",
    # "FluidShake",
    # "FluidShakeBox",
    # "Continuous",
    # "WaterDrop-XL",
    # "Water-3D",
    # "Sand-3D",
    # "Goop-3D"
]

# !mkdir -p datasets/deepmind/
# !mkdir -p datasets/local/

for DATASET in SELECTED_DATASETS:
    # !bash ./download_dataset.sh {DATASET} datasets/deepmind/
